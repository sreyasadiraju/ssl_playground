# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline

# %%
import os
import torch
import torchvision
import numpy as np
import matplotlib.pyplot as plt

from ssl_playground.data import MNIST64, SmallNORB

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
device
# Out:
# device(type='cpu')

# %%
os.getcwd()
# Out:
# '/Users/adiraju/issalab/ssl_playground/scripts'

# %%
mnist64 = MNIST64("../data/mnist64")

# %%
train_data, test_data = mnist64.make_data()

# %%
batch_size = 10
train_data_loader, test_data_loader = mnist64.make_loaders(train_data, test_data, batch_size)

# %%
def show_image(img):
    return plt.imshow(img.numpy(), cmap="gray")

# %%
trainiter = iter(train_data_loader)
data = next(trainiter)
images, labels = data

# %%
show_image(images[2,0])

# %%
small_norb = SmallNORB("../data/small_norb")

# %%
small_norb.create_small_norb(download=False, unzip=False, extract=True)
# Out:
# ...
# Loading info...: 100%|████████████████████████████████████████████████████████████████████████████████████████████| 24300/24300 [00:00<00:00, 619173.84it/s]

# %%
small_norb_categories = small_norb.dataset.categories
small_norb_categories
# Out:
# ['animal', 'human', 'airplane', 'truck', 'car']

# %%
small_norb.dataset.explore_random_examples(dataset_split="train")
